# %% [markdown]
# # Data Exploration - Binance Cryptocurrency Data
#
# Notebook สำหรับการสำรวจและวิเคราะห์ข้อมูลเบื้องต้น

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
# Load data from CSV
data_path = Path('../data/raw')
# df = pd.read_csv(data_path / 'your_data_file.csv')

# Display basic info
# print(f"Shape: {df.shape}")
# df.head()

# %% [markdown]
# ## 2. Data Overview

# %%
# Basic statistics
# df.describe()

# %%
# Check for missing values
# df.isnull().sum()

# %% [markdown]
# ## 3. Data Visualization

# %%
# Price chart example
# fig, ax = plt.subplots(figsize=(15, 6))
# ax.plot(df['timestamp'], df['close'])
# ax.set_title('Price Over Time')
# ax.set_xlabel('Date')
# ax.set_ylabel('Price (USDT)')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Calculate technical indicators
# Example: Simple Moving Average
# df['SMA_7'] = df['close'].rolling(window=7).mean()
# df['SMA_30'] = df['close'].rolling(window=30).mean()

# %% [markdown]
# ## 5. Save Processed Data

# %%
# Save processed data
# output_path = Path('../data/processed')
# df.to_csv(output_path / 'processed_data.csv', index=False)
# print('Saved processed data')
